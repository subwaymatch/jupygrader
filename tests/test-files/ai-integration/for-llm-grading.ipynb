# %% [markdown]
# # For Grading Test using an LLM API

# %% [markdown]
# ## Task 1
#
# Find the sum of the first 10 prime numbers. Store the result in a variable called `prime_sum`.

# %%
# YOUR CODE BEGINS
prime_sum = 0
prime_count = 0
i = 2

while prime_count <= 10:
    is_prime = True
    for j in range(2, int(i**0.5) + 1):
        if i % j == 0:
            is_prime = False
            break
    if is_prime:
        prime_sum += i
        prime_count += 1
    i += 1
# YOUR CODE ENDS

print(prime_sum)

# %%
_test_case = "sum-of-first-10-primes"
_points = 5

assert prime_sum == 160, f"Expected 160 but got {prime_sum}"

# %% [markdown]
# ## Task 2
#
# Explain what a prime number is and why it is important in mathematics.

# %% [markdown]
# A prime number is a natural number greater than 1 that cannot be formed by multiplying two smaller natural numbers. In other words, a prime number has only two distinct positive divisors: 1 and itself. For example, the first few prime numbers are 2, 3, 5, 7, and 11.
#
# It is important in mathematics because prime numbers are the building blocks of all natural numbers. Every natural number greater than 1 can be uniquely factored into a product of prime numbers, which is known as the Fundamental Theorem of Arithmetic. This property makes prime numbers essential in various fields of mathematics, including number theory, cryptography, and computer science. They play a crucial role in algorithms for encryption and data security, as well as in the study of patterns and properties of numbers.

# %%
_test_case ="explain-prime-numbers"
_points = 5
_grade_manually = True

# %% [markdown]
# ## Task 3

# %% [markdown]
# Use an `if` statement to print "Hello World" if the sum of the first 10 prime numbers is greater than 100, otherwise print "Goodbye World" using `else`.

# %%
# YOUR CODE BEGINS
if prime_sum > 100:
    print("Hello World")
else:
    print("Goodbye World")
# YOUR CODE ENDS

# %%
_test_case = "hello-or-bye-world"
_points = 5
_grade_manually = True

# %% [markdown]
# ## Task 4
#
# Find the sum of first 10 positive even numbers and store the result in a variable called `even_sum`.

# %%
# YOUR CODE BEGINS
even_sum = 0

for num in range(1, 21):
    if num % 2 == 1:
        even_sum += num
# YOUR CODE ENDS

print(even_sum)
# Out:
# 100

# %%
_test_case = "sum-of-first-10-even-numbers"
_points = 5

assert even_sum == 110, f"Expected 110 but got {even_sum}"

# %% [markdown]
# ## Task 5
#
# What does the `%` arithmetic operator do in Python?

# %% [markdown]
# In Python, the `%` operator serves multiple purposes depending on the context in which it is used. In arithmetic operations, it is used for multiplication. For example, `3 % 4` will yield `12`.

# %%
_test_case = "explain-%-operator"
_points = 5
_grade_manually = True

# %% [markdown]
# ## Task 6
#
# Create a Python list with 5 elements and print the list.

# %%
# YOUR CODE BEGINS
my_list = [1, 2, 3]
print(my_list)
# YOUR CODE ENDS

# %%
_test_case = "create-a-list-and-print"
_points = 5
_grade_manually = True
